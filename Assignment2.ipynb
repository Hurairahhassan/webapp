# %%
class_1={"name":"Machine Learning"
       }
class_2={"name":"Data science"
       }
students = {
"student_bc2202" : {
        "name" : "Hurairah hassan",
        "class_ml" : class_1, "marks_ml" : {
            "test_1" : 90,
            "test_2" : 95,
            "test_3" : 100,
            "mid" : 90,
            "final" : 93    
        },
        "class_ds" : class_2, "marks_ds":
        {
            "test_1" : 40,
            "test_2" : 45,
            "test_3" : 50,
            "mid" : 55,
            "final" : 60    
        }
},
"student_bc22021" : {
        "name" : "Ahsan Ali",
        "class_ml" : class_1, "marks_ml" : {
            "test_1" : 90,
            "test_2" : 95,
            "mid" : 80,
            "final" : 85    
        },
        "class_ds" : class_2,
        "marks_ds":
        {
            "test_1" : 41,
            "test_2" : 46,
            "mid" : 51,
            "final" : 56           
        }
},
"student_1003" : {"name" : "Ali", "class_ml" : class_1, "marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}},
"student_1004" : {"name" : "Anees", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 43, "test_2" : 49, "mid" : 54,
            "final" : 59}},
"student_1005" : {"name" : "Waqar", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 44, "test_2" : 50, "mid" : 55,
            "final" : 60}},
"student_1006" : {"name" : "Murtaza", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 45, "test_2" : 51, "mid" : 56,
            "final" : 61}},
"student_1007" : {"name" : "Afridi", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 46, "test_2" : 52, "mid" : 57,
            "final" : 62}},
"student_1008" : {"name" : "Wahab", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 47, "test_2" : 53, "mid" : 58,
            "final" : 63}},
"student_1009" : {"name" : "Sajid", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 48, "test_2" : 54, "mid" : 59,
            "final" : 64}},
"student_1010" : {"name" : "Tauqeer", "class_ml" : class_1,"marks_ml":{"test_1" : 42, "test_2" : 48, "mid" : 53,
            "final" : 58}, "class_ds" : class_2, "marks_ds":{"test_1" : 49, "test_2" : 55, "mid" : 60,
            "final" : 65}}
}
stud_id = input ("Give Student id: ")
stud_id = "student_" + stud_id
stud_class = input ("Give Student class:ml or ds: ")
stud_class_a = "marks_" + stud_class
stud_class_b = "class_" + stud_class
stud_exam = input ("Give Student exam:quiz1 or quiz2 or mid or final ")
print ("Marks of" , students[stud_id]["name"] , "in" , stud_class, stud_exam , "exam is" , 
       students[stud_id][stud_class_a][stud_exam])

# %%
class1={"name":"AI"
       }
class2={"name":"CNC"
       }
students = {
"student_1001" : {
        "name" : "arif",
        "class_ai" : class1, "marks_ai" : {
            "quiz1" : 90,
            "quiz2" : 95,
            "mid" : 80,
            "final" : 85    
        },
        "class_cnc" : class2, "marks_cnc":
        {
            "quiz1" : 40,
            "quiz2" : 45,
            "mid" : 50,
            "final" : 55    
        }
},
"student_1002" : {
        "name" : "babar",
        "class_ai" : class1, "marks_ai" : {
            "quiz1" : 90,
            "quiz2" : 95,
            "mid" : 80,
            "final" : 85    
        },
        "class_cnc" : class2,
        "marks_cnc":
        {
            "quiz1" : 41,
            "quiz2" : 46,
            "mid" : 51,
            "final" : 56           
        }
},
"student_1003" : {"name" : "waqar", "class_ai" : class1, "marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}},
"student_1004" : {"name" : "zakir", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 43, "quiz2" : 49, "mid" : 54,
            "final" : 59}},
"student_1005" : {"name" : "hussain", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 44, "quiz2" : 50, "mid" : 55,
            "final" : 60}},
"student_1006" : {"name" : "hasnain", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 45, "quiz2" : 51, "mid" : 56,
            "final" : 61}},
"student_1007" : {"name" : "javed", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 46, "quiz2" : 52, "mid" : 57,
            "final" : 62}},
"student_1008" : {"name" : "jawwad", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 47, "quiz2" : 53, "mid" : 58,
            "final" : 63}},
"student_1009" : {"name" : "aftab", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 48, "quiz2" : 54, "mid" : 59,
            "final" : 64}},
"student_1010" : {"name" : "iqbal", "class_ai" : class1,"marks_ai":{"quiz1" : 42, "quiz2" : 48, "mid" : 53,
            "final" : 58}, "class_cnc" : class2, "marks_cnc":{"quiz1" : 49, "quiz2" : 55, "mid" : 60,
            "final" : 65}}
}
stud_id = input ("Give Student id: ")
stud_id = "student_" + stud_id
stud_class = input ("Give Student class:ai or cnc: ")
stud_class_a = "marks_" + stud_class
stud_class_b = "class_" + stud_class
stud_exam = input ("Give Student exam:quiz1 or quiz2 or mid or final ")
print ("Marks of" , students[stud_id]["name"] , "in" , stud_class, stud_exam , "exam is" , 
       students[stud_id][stud_class_a][stud_exam])
# Out:
# Give Student id: 1009
# Give Student class:ai or cnc: ai
# Give Student exam:quiz1 or quiz2 or mid or final mid
# Marks of aftab in ai mid exam is 53
